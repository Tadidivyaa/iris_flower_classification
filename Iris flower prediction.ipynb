# %%
import numpy as np
import pandas as pd
import pickle
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Reading Dataset

# %%
data=pd.read_csv("iris flower dataset.csv")

# %%
data
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# # Basic Methods

# %%
data.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
data.head(10)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa
# 5           5.4          3.9           1.7          0.4  Iris-setosa
# 6           4.6          3.4           1.4          0.3  Iris-setosa
# 7           5.0          3.4           1.5          0.2  Iris-setosa
# 8           4.4          2.9           1.4          0.2  Iris-setosa
# 9           4.9          3.1           1.5          0.1  Iris-setosa

# %%
data.tail(10)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 140           6.7          3.1           5.6          2.4  Iris-virginica
# 141           6.9          3.1           5.1          2.3  Iris-virginica
# 142           5.8          2.7           5.1          1.9  Iris-virginica
# 143           6.8          3.2           5.9          2.3  Iris-virginica
# 144           6.7          3.3           5.7          2.5  Iris-virginica
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica

# %%
data.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
data.shape
# Out:
# (150, 5)

# %%
X=data.drop(["species"],axis=1)

# %%
y=data["species"]

# %%
X
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
y
# Out:
# 0         Iris-setosa
# 1         Iris-setosa
# 2         Iris-setosa
# 3         Iris-setosa
# 4         Iris-setosa
#             ...
# 145    Iris-virginica
# 146    Iris-virginica
# 147    Iris-virginica
# 148    Iris-virginica
# 149    Iris-virginica
# Name: species, Length: 150, dtype: object

# %%
data.species.value_counts()
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: species, dtype: int64

# %%
data["species"].replace({"Iris-setosa":0 , "Iris-versicolor":1 , "Iris-virginica":2} , inplace = True)

# %%
data
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  species
# 0             5.1          3.5           1.4          0.2        0
# 1             4.9          3.0           1.4          0.2        0
# 2             4.7          3.2           1.3          0.2        0
# 3             4.6          3.1           1.5          0.2        0
# 4             5.0          3.6           1.4          0.2        0
# ..            ...          ...           ...          ...      ...
# 145           6.7          3.0           5.2          2.3        2
# 146           6.3          2.5           5.0          1.9        2
# 147           6.5          3.0           5.2          2.0        2
# 148           6.2          3.4           5.4          2.3        2
# 149           5.9          3.0           5.1          1.8        2
#
# [150 rows x 5 columns]

# %% [markdown]
# # Splitting data into training and testing

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.33,random_state=30)

# %%
X_train
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 6             4.6          3.4           1.4          0.3
# 67            5.8          2.7           4.1          1.0
# 144           6.7          3.3           5.7          2.5
# 92            5.8          2.6           4.0          1.2
# 21            5.1          3.7           1.5          0.4
# ..            ...          ...           ...          ...
# 53            5.5          2.3           4.0          1.3
# 130           7.4          2.8           6.1          1.9
# 140           6.7          3.1           5.6          2.4
# 45            4.8          3.0           1.4          0.3
# 37            4.9          3.1           1.5          0.1
#
# [100 rows x 4 columns]

# %%
X_test
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 20            5.4          3.4           1.7          0.2
# 5             5.4          3.9           1.7          0.4
# 3             4.6          3.1           1.5          0.2
# 101           5.8          2.7           5.1          1.9
# 82            5.8          2.7           3.9          1.2
# 80            5.5          2.4           3.8          1.1
# 123           6.3          2.7           4.9          1.8
# 145           6.7          3.0           5.2          2.3
# 74            6.4          2.9           4.3          1.3
# 107           7.3          2.9           6.3          1.8
# 38            4.4          3.0           1.3          0.2
# 103           6.3          2.9           5.6          1.8
# 93            5.0          2.3           3.3          1.0
# 99            5.7          2.8           4.1          1.3
# 8             4.4          2.9           1.4          0.2
# ...

# %%
y_train
# Out:
# 6      0
# 67     1
# 144    2
# 92     1
# 21     0
#       ..
# 53     1
# 130    2
# 140    2
# 45     0
# 37     0
# Name: species, Length: 100, dtype: int64

# %% [markdown]
# # Linear Regression

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(X_test)

# %%
y_pred
# Out:
# array([-5.77949446e-02,  2.51194453e-02,  2.53232570e-02,  1.75757260e+00,
#         1.05722062e+00,  1.03619251e+00,  1.58777136e+00,  1.89000251e+00,
#         1.11423519e+00,  1.75030403e+00,  1.53829396e-02,  1.72410541e+00,
#         9.36162945e-01,  1.16779298e+00,  4.56983107e-02,  1.13963443e+00,
#        -1.97711590e-01, -2.62301928e-02,  6.21727422e-02,  1.41703261e+00,
#         1.43551138e+00, -1.47784759e-03, -9.37814048e-02, -9.95605569e-02,
#         1.95702924e+00,  1.96996890e+00,  1.57453290e+00,  2.05715252e+00,
#        -3.95767135e-02,  1.19940215e+00,  1.77487647e+00,  9.51774351e-01,
#         1.81789147e+00,  1.58787942e+00,  2.16877249e+00,  1.83428790e+00,
#         9.03480782e-01,  1.67266002e+00,  1.09510951e+00,  1.52008202e+00,
#         2.01363695e+00,  1.90743572e+00, -2.68600682e-01,  1.36748350e+00,
#         1.72514482e+00,  1.25848471e+00,  1.21080797e+00,  1.18577118e+00,
#         1.19659843e+00,  1.16363181e+00])

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_pred)
# Out:
# 0.9182100977614087

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(y_test,y_pred)
# Out:
# 0.051167762840462705

# %%
Results=pd.DataFrame(columns=['species','Predicted'])
Results['species']=y_test
Results['Predicted']=y_pred
Results['ID']=Results.index
Results.head(15)
# Out:
#      species  Predicted   ID
# 20         0  -0.057795   20
# 5          0   0.025119    5
# 3          0   0.025323    3
# 101        2   1.757573  101
# 82         1   1.057221   82
# 80         1   1.036193   80
# 123        2   1.587771  123
# 145        2   1.890003  145
# 74         1   1.114235   74
# 107        2   1.750304  107
# 38         0   0.015383   38
# 103        2   1.724105  103
# 93         1   0.936163   93
# 99         1   1.167793   99
# 8          0   0.045698    8

# %% [markdown]
# # Correlation

# %%
import matplotlib.pyplot as plt
import seaborn as sns
corr=data.corr()
corr
# Out:
#               sepal_length  sepal_width  petal_length  petal_width   species
# sepal_length      1.000000    -0.109369      0.871754     0.817954  0.782561
# sepal_width      -0.109369     1.000000     -0.420516    -0.356544 -0.419446
# petal_length      0.871754    -0.420516      1.000000     0.962757  0.949043
# petal_width       0.817954    -0.356544      0.962757     1.000000  0.956464
# species           0.782561    -0.419446      0.949043     0.956464  1.000000

# %%
corr = data.corr()
plt.figure(figsize=(10,8))
sns.heatmap(corr,annot=True,linewidth=5)
plt.show()

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier()
rf.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred= rf.predict(X_test)
y_pred
# Out:
# array([0, 0, 0, 2, 1, 1, 2, 2, 1, 2, 0, 2, 1, 1, 0, 1, 0, 0, 0, 1, 1, 0,
#        0, 0, 2, 2, 2, 2, 0, 1, 2, 1, 2, 2, 2, 2, 1, 2, 1, 1, 2, 2, 0, 1,
#        2, 1, 1, 1, 1, 1], dtype=int64)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)
# Out:
# 0.94

# %% [markdown]
# # Ridge Regression

# %%
from sklearn.model_selection import GridSearchCV # GridSearchCV is a technique for finding the optimal parameter values from a given set of parameters in a grid
from sklearn.linear_model import Ridge
alpha = [1e-15, 1e-10, 1e-8, 1e-4, 1e-3,1e-2, 1, 5, 10, 20,30]

ridge = Ridge()
parameters = {'alpha': alpha}

ridge_regressor = GridSearchCV(ridge, parameters)
ridge_regressor.fit(X_train, y_train)
# Out:
# GridSearchCV(estimator=Ridge(),
#              param_grid={'alpha': [1e-15, 1e-10, 1e-08, 0.0001, 0.001, 0.01, 1,
#                                    5, 10, 20, 30]})

# %%
ridge_regressor.best_params_#it finds the best parameter
# Out:
# {'alpha': 1}

# %%
ridge=Ridge(alpha=1)
ridge.fit(X_train,y_train)
y_pred_ridge=ridge.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error
Ridge_Error=mean_squared_error(y_pred_ridge,y_test)
Ridge_Error
# Out:
# 0.05101390192019836
